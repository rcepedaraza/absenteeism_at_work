# %%
from Absenteeism_model import *
model = absenteeism_model("model", "scaler")
model.load_and_clean_data("Absenteeism_new_data.csv")
model.predicted_outputs()
# Out:
#     Reason_1  Reason_2  Reason_3  Reason_4  Month  Transportation Expense  \
# 0          0       0.0         0         1      6                     179
# 1          1       0.0         0         0      6                     361
# 2          0       0.0         0         1      6                     155
# 3          0       0.0         0         1      6                     179
# 4          1       0.0         0         0      6                     155
# 5          1       0.0         0         0      6                     225
# 6          1       0.0         0         0      6                     118
# 7          0       0.0         0         1      6                     179
# 8          0       0.0         0         1      6                     118
# 9          1       0.0         0         0      6                     118
# 10         0       0.0         0         1      6                     378
# 11         0       0.0         1         0      6                     118
# ...

# %%
import pymysql

# %%
connex = pymysql.connect(database = "predicted_outputs", user="root", password="Totustuus23")

# %%
cursor = connex.cursor()

# %% [markdown]
# ### Checkpoint

# %%
df_new_obs = model.predicted_outputs()

# %% [markdown]
# ### .execute( )

# %%
cursor.execute("SELECT * FROM predicted_outputs")
# Out:
# 0

# %% [markdown]
# Python variables can be used as arguments of the __.execute( )__ method as well
#
# We will create a structure that will insert the ro's information from __df_new_obs__ into a row in our database in MySQL ("predicted_outputs").

# %% [markdown]
# ## Creating the INSERT Statement

# %%
insert_query = "INSERT INTO predicted_outputs VALUES"
insert_query
# Out:
# 'INSERT INTO predicted_outputs VALUES'

# %%
df_new_obs.shape
# Out:
# (40, 13)

# %%
df_new_obs.columns.values
# Out:
# array(['Reason_1', 'Reason_2', 'Reason_3', 'Reason_4', 'Month',
#        'Transportation Expense', 'Age', 'Body Mass Index', 'Education',
#        'Children', 'Pets', 'Probability', 'Prediction'], dtype=object)

# %%
for i in range(df_new_obs.shape[0]):
    insert_query +='('
    
    for j in range(df_new_obs.shape[1]):
        insert_query += str(df_new_obs[df_new_obs.columns.values[j]][i]) + ', '
    
    insert_query = insert_query[:-2] + '), '
insert_query = insert_query[:-2] + ';'

# %%
insert_query
# Out:
# 'INSERT INTO predicted_outputs VALUES(0, 0.0, 0, 1, 6, 179, 30, 19, 1, 0, 0, 0.16498928381864866, 0), (1, 0.0, 0, 0, 6, 361, 28, 27, 0, 1, 4, 0.8488532865920595, 1), (0, 0.0, 0, 1, 6, 155, 34, 25, 0, 2, 0, 0.32233259347405957, 0), (0, 0.0, 0, 1, 6, 179, 40, 22, 1, 2, 0, 0.27255251265613467, 0), (1, 0.0, 0, 0, 6, 155, 34, 25, 0, 2, 0, 0.753418714373868, 1), (1, 0.0, 0, 0, 6, 225, 28, 24, 0, 1, 2, 0.717802840113377, 1), (1, 0.0, 0, 0, 6, 118, 46, 25, 0, 2, 0, 0.58275864929247, 1), (0, 0.0, 0, 1, 6, 179, 30, 19, 1, 0, 0, 0.16498928381864866, 0), (0, 0.0, 0, 1, 6, 118, 37, 28, 0, 0, 0, 0.14198977166566812, 0), (1, 0.0, 0, 0, 6, 118, 37, 28, 0, 0, 0, 0.5152805265548128, 1), (0, 0.0, 0, 1, 6, 378, 36, 21, 0, 2, 4, 0.42305657645310263, 0), (0, 0.0, 1, 0, 6, 118, 50, 31, 0, 1, 0, 0.6609255375231461, 1), (0, 0.0, 1, 0, 6, 233, 31, 21, 1, 1, 8, 0.42807556415265563, 0), (0, 0.0, 0, 1, 6, 179, 30, 19, 1, 0, 0, 0.16498928381864866, 0), (0, 0.0, 0, 0, 6, 235, 48, 33, 0, 1, 5, 0.06501760206804405, 
# ...

# %%
cursor.execute(insert_query)
# Out:
# 40

# %%
connex.commit()

# %%
connex.close()
